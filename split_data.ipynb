# %%
import pandas as pd

df = pd.read_csv("SHA256SUMS.txt", header=None, delim_whitespace=True)
# Out:
# /var/folders/wj/8406k4zs34b1rtmbdltdknl00000gp/T/ipykernel_70272/1321448141.py:3: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv("SHA256SUMS.txt", header=None, delim_whitespace=True)

# %%
df.head()
# Out:
#                                                    0  \
# 0  a688ad339cb18a877f53dea5d900186ac50170507ad72e...
# 1  26794be6ea7916cd4b4017b45b9c34c3c31f645a03a9cd...
# 2  af51555bca6c6caa60ac75759ad9f022cf86a7ce8e24c9...
# 3  3f721831529e9604c99e3bd999483321e0e0648c598735...
# 4  dc00f099dadf5c38ead73ad9e768cee82b893402d02d58...
#
#                                                    1
# 0                                    IMAGE_FILENAMES
# 1                                        LICENSE.txt
# 2                                             README
# 3  files/p10/p10000032/s50414267/02aa804e-bde0afd...
# 4  files/p10/p10000032/s50414267/174413ec-4ec4c1f...
